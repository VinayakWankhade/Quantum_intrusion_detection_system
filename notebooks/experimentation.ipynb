# %%
df = pd.read_csv("../data/processed/cicids_merged.csv")

print(df.shape)
print(df.head())
print(df.info())
print(df["Label"].value_counts())
# Out:
# (2313810, 78)
#    Protocol  Flow Duration  Total Fwd Packets  Total Backward Packets  \
# 0         6              4                  2                       0
# 1         6              1                  2                       0
# 2         6              3                  2                       0
# 3         6              1                  2                       0
# 4         6            609                  7                       4
#
#    Fwd Packets Length Total  Bwd Packets Length Total  Fwd Packet Length Max  \
# 0                        12                         0                      6
# 1                        12                         0                      6
# 2                        12                         0                      6
# 3                        12                         0                      6
# 4                       484                       414                    233
#
# ...

# %%
import pandas as pd

df = pd.read_csv("../data/processed/nslkdd_merged.csv")

print(df.shape)
print(df.head())
print(df.info())
print(df["label"].value_counts())
# Out:
# (148517, 42)
#   duration protocol_type service  flag  src_bytes  dst_bytes  land  \
# 0      tcp      ftp_data      SF   491          0          0     0
# 1      udp         other      SF   146          0          0     0
# 2      tcp       private      S0     0          0          0     0
# 3      tcp          http      SF   232       8153          0     0
# 4      tcp          http      SF   199        420          0     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                0.17
# 1               0       0    0  ...                0.00
# 2               0       0    0  ...                0.10
# 3               0       0    0  ...                1.00
# 4               0       0    0  ...                1.00
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.03                    0.17
# 1                    0.60                    0.88
# 2                    0.05                    0.00
# ...

# %%
import pandas as pd

df = pd.read_csv("../data/processed/train_dataset.csv")

print(df["label"].value_counts())
# Out:
# label
# 21    58221
# 18    18777
# 20    16468
# 19     8840
# 15     3414
# 17     3334
# 16     2394
# 14     1114
# 12      962
# 11      875
# 13      762
# 10      349
# 7       293
# 9       234
# 6       214
# 8       196
# 4       150
# 0       144
# 5       143
# 3       138
# 1       114
# 2        80
# Name: count, dtype: int64

# %%
import pandas as pd

df = pd.read_csv("../data/processed/train_dataset.csv")

df["label"] = df["label"].apply(lambda x: 0 if x == 21 else 1)

print(df["label"].value_counts())
# Out:
# label
# 1    58995
# 0    58221
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x=df["label"])

plt.title("Normal vs Attack Distribution")

plt.show()
